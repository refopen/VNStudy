# %%
# !df -h
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay          49G   25G   22G  54% /
# tmpfs            64M     0   64M   0% /dev
# tmpfs           6.4G     0  6.4G   0% /sys/fs/cgroup
# tmpfs           6.4G  8.0K  6.4G   1% /var/colab
# /dev/sda1        55G   27G   29G  49% /etc/hosts
# shm             6.0G  4.0K  6.0G   1% /dev/shm
# tmpfs           6.4G     0  6.4G   0% /proc/acpi
# tmpfs           6.4G     0  6.4G   0% /proc/scsi
# tmpfs           6.4G     0  6.4G   0% /sys/firmware

# %% [markdown]
# # 새 섹션

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13335188 kB
# MemFree:        11021228 kB
# MemAvailable:   12524536 kB
# Buffers:           69968 kB
# Cached:          1591068 kB
# SwapCached:            0 kB
# Active:           677060 kB
# Inactive:        1393992 kB
# Active(anon):     387368 kB
# Inactive(anon):      308 kB
# Active(file):     289692 kB
# Inactive(file):  1393684 kB
# Unevictable:           0 kB
# Mlocked:               0 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:               864 kB
# Writeback:             0 kB
# AnonPages:        410264 kB
# Mapped:           217108 kB
# Shmem:               844 kB
# Slab:             152316 kB
# SReclaimable:     121876 kB
# SUnreclaim:        30440 kB
# KernelStack:        3552 kB
# PageTables:         5300 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6667592 kB
# Committed_AS:    2762200 kB
# VmallocTotal:   34359738367 kB
# VmallocUsed:           0 kB
# VmallocChunk:          0 kB
# AnonHugePages:         0 kB
# ShmemHugePages:        0 kB
# ShmemPmdMapped:        0 kB
# HugePages_Total:       0
# HugePages_Free:        0
# HugePages_Rsvd:        0
# HugePages_Surp:        0
# Hugepagesize:       2048 kB
# DirectMap4k:       63476 kB
# DirectMap2M:     5179392 kB
# DirectMap1G:    10485760 kB

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2200.000
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs
# bogomips	: 4400.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2200.000
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs
# bogomips	: 4400.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:

# %%
# !nvidia-smi
# Out:
# Mon Nov 18 10:14:46 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 430.50       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   63C    P8    34W / 149W |      0MiB / 11441MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 1.15.0

# %%
# !python drive/deep_learning/alexnet/train.py
# Out:
# python3: can't open file 'drive/deep_learning/alexnet/train.py': [Errno 2] No such file or directory

# %%
# !git clone https://github.com/ChiWeiHsiao/DeepVO-pytorch.git
# Out:
# Cloning into 'DeepVO-pytorch'...
# remote: Enumerating objects: 450, done.
# remote: Total 450 (delta 0), reused 0 (delta 0), pack-reused 450
# Receiving objects: 100% (450/450), 5.25 MiB | 3.78 MiB/s, done.
# Resolving deltas: 100% (261/261), done.

# %%
cd DeepVO-pytorch/
# Out:
# /content/DeepVO-pytorch

# %%
# !python DeepVO-pytorch/main.py
# Out:
# Create new data info
# Traceback (most recent call last):
#   File "DeepVO-pytorch/main.py", line 30, in <module>
#     train_df = get_data_info(folder_list=par.train_video, seq_len_range=par.seq_len, overlap=1, sample_times=par.sample_times)
#   File "/content/DeepVO-pytorch/data_helper.py", line 20, in get_data_info
#     poses = np.load('{}{}.npy'.format(par.pose_dir, folder))  # (n_images, 6)
#   File "/usr/local/lib/python3.6/dist-packages/numpy/lib/npyio.py", line 428, in load
#     fid = open(os_fspath(file), "rb")
# FileNotFoundError: [Errno 2] No such file or directory: '/nfs/nas12.ethz.ch/fs1201/infk_ivc_students/cvg-students/chsiao/KITTI//pose_GT/00.npy'

# %%
ls
# Out:
# data_helper.py      helper.py  model.py   preprocess.py  records/
# datainfo/           KITTI/     models/    __pycache__/   test.py
# Dataloader_loss.py  main.py    params.py  Readme.md      visualize.py

# %%
# !python main.py
# Out:
# Load data info from datainfo/train_df_t000102050809_v04060710_pNone_seq5x7_sample3.pickle
# Number of samples in training dataset:  11233
# Number of samples in validation dataset:  730
# ==================================================
# CUDA used.
# Traceback (most recent call last):
#   File "main.py", line 84, in <module>
#     M_deepvo.load_state_dict(torch.load(par.load_model_path))
#   File "/usr/local/lib/python3.6/dist-packages/torch/serialization.py", line 419, in load
#     f = open(f, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: 'models/t000102050809_v04060710_im184x608_s5x7_b8_rnn1000_optAdagrad_lr0.0005.model.train'

# %%
mkdir models
# Out:
# mkdir: cannot create directory ‘models’: File exists

# %%
ls models

# %%
cd models
from google.colab import files
uploaded = files.upload()
# Out:
#   File "<ipython-input-21-5aec097992f6>", line 1
#     cd models
#             ^
# SyntaxError: invalid syntax

# %%
cd models
ls
# Out:
#   File "<ipython-input-22-2fd8e27c3a63>", line 1
#     cd models
#             ^
# SyntaxError: invalid syntax

# %%
cd models
# Out:
# /content/DeepVO-pytorch/models

# %%
ls
# Out:
# data_helper.py      helper.py  model.py   preprocess.py  records/
# datainfo/           KITTI/     models/    __pycache__/   test.py
# Dataloader_loss.py  main.py    params.py  Readme.md      visualize.py

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a44174d0-84e8-4fbc-a95a-401649a76b32" name="files[]" multiple disabled />
#      <output id="result-a44174d0-84e8-4fbc-a95a-401649a76b32">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving t000102050809_v04060710_im184x608_s5x7_b8_rnn1000_optAdagrad_lr0.0005.model.train to t000102050809_v04060710_im184x608_s5x7_b8_rnn1000_optAdagrad_lr0.0005.model.train

# %%
ll
# Out:
# total 4
# drwxr-xr-x 1 root 4096 Nov  6 16:17 sample_data/

# %%
# Out:
# '/content/DeepVO-pytorch'

# %%
cd ..
# Out:
# /content

# %%
ls
# Out:
# bin/      dev/   lib32/  opt/   sbin/   tensorflow-2.0.0/  var/
# boot/     etc/   lib64/  proc/  srv/    tmp/
# content/  home/  media/  root/  swift/  tools/
# datalab/  lib/   mnt/    run/   sys/    usr/

# %%
cd content/
# Out:
# /content

# %%
ls
# Out:
# data_helper.py      helper.py  model.py       Readme.md
# datainfo/           KITTI/     params.py      test.py
# Dataloader_loss.py  main.py    preprocess.py  visualize.py

# %%
ls
# Out:
# data_helper.py      helper.py  model.py       Readme.md
# datainfo/           KITTI/     params.py      test.py
# Dataloader_loss.py  main.py    preprocess.py  visualize.py

# %%
# !python main.py
# Out:
# Load data info from datainfo/train_df_t000102050809_v04060710_pNone_seq5x7_sample3.pickle
# Number of samples in training dataset:  11233
# Number of samples in validation dataset:  730
# ==================================================
# CUDA used.
# Traceback (most recent call last):
#   File "main.py", line 84, in <module>
#     M_deepvo.load_state_dict(torch.load(par.load_model_path))
#   File "/usr/local/lib/python3.6/dist-packages/torch/serialization.py", line 419, in load
#     f = open(f, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: 'models/t000102050809_v04060710_im184x608_s5x7_b8_rnn1000_optAdagrad_lr0.0005.model.train'

# %%
from google.colab import drive
drive.mount('/content/gdrive/')

# %%
ls
# Out:
# DeepVO-pytorch/  gdrive/  sample_data/

# %%
cd gdrive/
# Out:
# /content/gdrive

# %%
ls
# Out:
# 'My Drive'/

# %%
cd My Drive
# Out:
# /content/gdrive/My Drive

# %%
cd Colab test
# Out:
# /content/gdrive/My Drive/Colab test

# %%
ls
# Out:
# data_helper.py      helper.py  model.py   preprocess.py  visualize.py
# datainfo/           KITTI/     Models/    Readme.md
# Dataloader_loss.py  main.py    params.py  test.py

# %%
# !python main.py
# Out:
# Load data info from datainfo/train_df_t000102050809_v04060710_pNone_seq5x7_sample3.pickle
# Number of samples in training dataset:  11233
# Number of samples in validation dataset:  730
# ==================================================
# CUDA used.
# Load model from:  models/t000102050809_v04060710_im184x608_s5x7_b8_rnn1000_optAdagrad_lr0.0005.model.train
# Load optimizer from:  models/t000102050809_v04060710_im184x608_s5x7_b8_rnn1000_optAdagrad_lr0.0005.optimizer.train
# Record loss in:  records/t000102050809_v04060710_im184x608_s5x7_b8_rnn1000_optAdagrad_lr0.0005.txt
# ==================================================
# Traceback (most recent call last):
#   File "main.py", line 102, in <module>
#     for _, t_x, t_y in train_dl:
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 819, in __next__
#     return self._process_data(data)
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 846, in _process_data
#     data.reraise()
#   File "/usr/local/lib/python3.6/dist-packages/torch/_utils.py", line 385, in reraise
#     raise self.exc_type(msg)
# ValueError: Caught ValueError in DataLoader worker process 0.
# Original Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/_utils/worker.py", line 178, in _worker_loop
#     data = fetcher.fetch(index)
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/_utils/fetch.py", line 44, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/_utils/fetch.py", line 44, in <listcomp>
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/content/gdrive/My Drive/Colab test/data_helper.py", line 201, in __getitem__
#     groundtruth_rotation = raw_groundtruth[1][0].reshape((3, 3)).T # opposite rotation of the first frame
# ValueError: cannot reshape array of size 0 into shape (3,3)

# %%
# !mv Models models

# %%
ls
# Out:
# data_helper.py      helper.py  model.py   preprocess.py  records/
# datainfo/           KITTI/     models/    __pycache__/   test.py
# Dataloader_loss.py  main.py    params.py  Readme.md      visualize.py

# %%
# !python test.py
# Out:
# Load model from:  models/t000102050809_v04060710_im184x608_s5x7_b8_rnn1000_optAdagrad_lr0.0005.model.train
# seq_len = 6,  overlap = 5
# Folder 04 finish in 0.00234222412109375 sec
# len(answer):  1
# expect len:  0
# Predict use 0.09876251220703125 sec
# Traceback (most recent call last):
#   File "test.py", line 125, in <module>
#     angle_loss = np.sum((answer[t][:3] - gt_pose[t,:3]) ** 2)
# IndexError: list index out of range

# %%
# !python data_helper.py
# Out:
# Traceback (most recent call last):
#   File "data_helper.py", line 252, in <module>
#     df = get_data_info(folder_list, seq_len_range, overlap, sample_times)
#   File "data_helper.py", line 20, in get_data_info
#     poses = np.load('{}{}.npy'.format(par.pose_dir, folder))  # (n_images, 6)
#   File "/usr/local/lib/python3.6/dist-packages/numpy/lib/npyio.py", line 428, in load
#     fid = open(os_fspath(file), "rb")
# FileNotFoundError: [Errno 2] No such file or directory: './pose_GT/00.npy'

# %%
# !python preprocess.py
# Out:
# Transforming ./pose_GT/00.txt...
# Video 00: shape=(4541, 15)
# Transforming ./pose_GT/01.txt...
# Video 01: shape=(1101, 15)
# Transforming ./pose_GT/02.txt...
# Video 02: shape=(4661, 15)
# Transforming ./pose_GT/03.txt...
# Video 03: shape=(801, 15)
# Transforming ./pose_GT/04.txt...
# Video 04: shape=(271, 15)
# Transforming ./pose_GT/05.txt...
# Video 05: shape=(2761, 15)
# Transforming ./pose_GT/06.txt...
# Video 06: shape=(1101, 15)
# Transforming ./pose_GT/07.txt...
# Video 07: shape=(1101, 15)
# Transforming ./pose_GT/08.txt...
# Video 08: shape=(4071, 15)
# Transforming ./pose_GT/09.txt...
# Video 09: shape=(1591, 15)
# Transforming ./pose_GT/10.txt...
# Video 10: shape=(1201, 15)
# elapsed time = 5.762853384017944
# Numbers of frames in training dataset: 0
# Traceback (most recent call last):
#   File "preprocess.py", line 119, in <module>
#     calculate_rgb_mean_std(image_path_list, minus_point_5=True)
#   File "preprocess.py", line 84, in calculate_rgb_mean_std
#     mean_tensor =  [v / cnt_pixels for v in mean_tensor]
#   File "preprocess.py", line 84, in <listcomp>
#     mean_tensor =  [v / cnt_pixels for v in mean_tensor]
# ZeroDivisionError: division by zero

# %%
ls
# Out:
# downloader.sh

# %%
cd KITTI/
# Out:
# /content/gdrive/My Drive/Colab test/KITTI

# %%
# !./downloader.sh

# %%
ls -l
# Out:
# total 2
# -rw------- 1 root root 1516 Nov 18 13:28 downloader.sh

# %%
# !chmod +x downloader.sh

# %%
ls
# Out:
# sample_data/
