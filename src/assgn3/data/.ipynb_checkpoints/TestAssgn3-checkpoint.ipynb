# %%
import numpy as np
import matplotlib.pyplot as plt
import skimage.io

# %%
data = np.load("../data/temple_coords.npz")

pts1 = data['pts1']
pts1[:, 0] = 480 - pts1[:, 0]

# pts2 = data['pts2']
# pts2[:, 0] = 480 - pts2[:, 0]
np.savez("temple_coords.npz", pts1=pts1)
print(data.files)
# Out:
# ['pts1', 'pts2']

# %%
# im1 = np.fliplr(im1)
# im1_updated

# %%
data1 = np.load("../data/some_corresp_updated.npz")

# %%
p1 = data1['pts1'].astype(float)
p2 = data1['pts2'].astype(float)
print(p1.shape, p2.shape, p1.dtype, p2.dtype)
im1 = skimage.io.imread("./im1_updated.png").astype(float)/255.0
skimage.io.imsave("./im1_updated.png", np.fliplr(skimage.io.imread("./im1.png")))
# im2 = skimage.io.imread("./im1.png").astype(float)/255.0
# im1 = np.flip(im1, axis=0)
print(im1.shape)

datat = np.load("../data/temple_coords.npz")
t1 = datat["pts1"]
# t1[:,0] = 480 - t1[:,0]
# Out:
# (110, 2) (110, 2) float64 float64
# (640, 480, 4)

# %%
fig, ax = plt.subplots(figsize=(8,10))
ax.scatter(p1[:,0], p1[:,1], c='r', label='some_corresp.npz')
ax.scatter(t1[:,0], t1[:,1], c='b', label='temple_coords.npz')
# ax.scatter(t1o[:,0], t1o[:,1], c='g', label='temple_coords_old')

ax.imshow(im1)
ax.legend()
plt.show()

# fig, ax = plt.subplots(figsize=(8,10))
# ax.scatter(p1[:,0], p1[:,1], c='r', label='pts1')
# ax.scatter(p2[:,0], 500-p2[:,1], c='b', label='pts2')
# ax.imshow(im2)
# ax.legend()
plt.show()

# %%
import os
os.getcwd()
# Out:
# '/Users/anand/cmu/16385-vision-ta/hw/hw3/data'

# %%
data = np.load("../../assgn3/data/some_corresp.npz")
p1 = data['pts1'].astype(float)
p2 = data['pts2'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-8e5aa898c9cb> in <module>
# ----> 1 data = np.load("../../assgn3/data/some_corresp.npz")
#       2 p1 = data['pts1'].astype(float)
#       3 p2 = data['pts2'].astype(float)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     426         own_fid = False
#     427     else:
# --> 428         fid = open(os_fspath(file), "rb")
#     429         own_fid = True
#     430
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../assgn3/data/some_corresp.npz'

# %%
data = np.load("../../assgn3_piz/data/some_corresp.npz")
p1p = data['pts1'].astype(float)
p2p = data['pts2'].astype(float)

print(np.sum(np.abs(p1p - p1)))
print(np.sum(np.abs(p2p - p2)))

# %%
import scipy.io
mat = scipy.io.loadmat("../../assgn3_old/data/someCorresp.mat")

# %%
p1o = mat['pts1']
p2o = mat['pts2']

# %%
print(np.sum(np.abs(p1o - p1)))
print(np.sum(np.abs(p2o - p2)))

# %%
tt = scipy.io.loadmat("../../assgn3_old/data/templeCoords.mat")
t1o = tt['pts1']

# %%
np.allclose(t1o, t1)

# %%
print(t1o)
print(t1)

# %%
data['pts1'][:, 0]
# Out:
# array([232, 285, 226, 331, 317, 274, 325, 138, 341, 262, 271, 291, 330,
#        212, 285, 277, 294, 330, 306, 385, 171, 274, 358, 221, 226, 284,
#        160, 394, 246, 353, 292, 339, 274, 342, 154, 215, 281, 232, 104,
#        139, 154, 270, 332, 231, 284, 311, 132, 135, 260, 311, 236, 190,
#        237, 183, 204, 372, 153, 280, 155, 215, 277, 221, 289, 289, 290,
#        281, 170, 293, 230, 235, 298, 326, 155, 240, 170, 153, 207, 122,
#        171, 381, 187, 280, 127, 158, 104, 227, 134, 245, 294, 222, 327,
#        224, 227, 128, 222, 185, 277, 242, 127, 134, 237, 279, 136, 290,
#        132, 244, 224, 141, 227, 160], dtype=uint16)

# %%
pts1 = data['pts1']
pts1[:, 0] = 480 - pts1[:, 0]

# %%
pts1[:, 0]
# Out:
# array([248, 195, 254, 149, 163, 206, 155, 342, 139, 218, 209, 189, 150,
#        268, 195, 203, 186, 150, 174,  95, 309, 206, 122, 259, 254, 196,
#        320,  86, 234, 127, 188, 141, 206, 138, 326, 265, 199, 248, 376,
#        341, 326, 210, 148, 249, 196, 169, 348, 345, 220, 169, 244, 290,
#        243, 297, 276, 108, 327, 200, 325, 265, 203, 259, 191, 191, 190,
#        199, 310, 187, 250, 245, 182, 154, 325, 240, 310, 327, 273, 358,
#        309,  99, 293, 200, 353, 322, 376, 253, 346, 235, 186, 258, 153,
#        256, 253, 352, 258, 295, 203, 238, 353, 346, 243, 201, 344, 190,
#        348, 236, 256, 339, 253, 320], dtype=uint16)

# %%
data = np.load("../data/temple_coords.npz")

# %%
# Out:
# ['pts1']
